# %% [markdown]
# ## 각도기
#
# 각에서 0도 초과 90도 미만은 예각, 90도는 직각, 90도 초과 180도 미만은 둔각 180도는 평각으로 분류합니다. 각 angle이 매개변수로 주어질 때 예각일 때 1, 직각일 때 2, 둔각일 때 3, 평각일 때 4를 return하도록 solution 함수를 완성해주세요.
#
# ![image.png](attachment:450ac4a8-7cb3-4f47-823e-6d104eb25ad9.png)

# %%
def solution(angle):
    if 0<angle<90:
        return 1
    if angle == 90:
        return 2
    if 90<angle<180:
        return 3
    if angle == 180:
        return 4

# %% [markdown]
# ## 특정 문자 제거하기
#
# 문자열 my_string과 문자 letter이 매개변수로 주어집니다. my_string에서 letter를 제거한 문자열을 return하도록 solution 함수를 완성해주세요.
#
# ![image.png](attachment:9c6e474d-45ea-485b-b0b8-32545c31c265.png)

# %%
def solution(my_string, letter):
    answer = []
    for l in my_string:
        if l == letter:
            pass
        else:
            answer.append(l)
    result = "".join(answer)
    return result

# %% [markdown]
# ## 문자 반복 출력하기
#
# 문자열 my_string과 정수 n이 매개변수로 주어질 때, my_string에 들어있는 각 문자를 n만큼 반복한 문자열을 return 하도록 solution 함수를 완성해보세요.
#
# ![image.png](attachment:3bb1a4f5-1b0e-4c97-a8c3-322fa07deaed.png)

# %%
def solution(my_string, n):
    answer = ''
    for c in my_string:
        answer += c*n
    return answer

# %% [markdown]
# ## 짝수 홀수 개수
#
# 정수가 담긴 리스트 num_list가 주어질 때, num_list의 원소 중 짝수와 홀수의 개수를 담은 배열을 return 하도록 solution 함수를 완성해보세요.
#
# ![image.png](attachment:8006738e-2cb9-42a0-a14a-95897d4c2ad3.png)

# %%
def solution(num_list):
    even = [num for num in num_list if num % 2 == 0]
    odd = [num for num in num_list if num % 2]
    return [len(even), len(odd)]

# %% [markdown]
# ## 직각삼각형 출력하기
#
# "*"의 높이와 너비를 1이라고 했을 때, "*"을 이용해 직각 이등변 삼각형을 그리려고합니다. 정수 n 이 주어지면 높이와 너비가 n 인 직각 이등변 삼각형을 출력하도록 코드를 작성해보세요.
#
# ![image.png](attachment:00350196-936f-489b-af4b-c37656b1cd0d.png)

# %%
def triangle(n):
    for i in range(1,n+1):
        print(i*'*')

# %% [markdown]
# ## 문자열 뒤집기
#
# 문자열 my_string이 매개변수로 주어집니다. my_string을 거꾸로 뒤집은 문자열을 return하도록 solution 함수를 완성해주세요.
#
# ![image.png](attachment:d74dcb99-a5d6-4b63-9b65-1030663037f6.png)

# %%
def solution(my_string):
    r=''
    for c in my_string:
        r = c + r
    return r

# %% [markdown]
# ## 배열 뒤집기
#
# 정수가 들어 있는 배열 num_list가 매개변수로 주어집니다. num_list의 원소의 순서를 거꾸로 뒤집은 배열을 return하도록 solution 함수를 완성해주세요.
#
# ![image.png](attachment:ce144b4d-cef4-4b84-b66c-3b689f9beeb3.png)

# %%
def solution(num_list):
    return num_list[::-1]

# %% [markdown]
# ## 나이 출력
#
# 머쓱이는 40살인 선생님이 몇 년도에 태어났는지 궁금해졌습니다. 나이 age가 주어질 때, 2022년을 기준 출생 연도를 return 하는 solution 함수를 완성해주세요. </br>
#
# ![image.png](attachment:c8a229b1-d8fd-42d5-a82c-4b763dc9e039.png)

# %% [markdown]
# ## 아이스 아메리카노
#
# 머쓱이는 추운 날에도 아이스 아메리카노만 마십니다. 아이스 아메리카노는 한잔에 5,500원입니다. 머쓱이가 가지고 있는 돈 money가 매개변수로 주어질 때, 머쓱이가 최대로 마실 수 있는 아메리카노의 잔 수와 남는 돈을 순서대로 담은 배열을 return 하도록 solution 함수를 완성해보세요. </br>
#
# ![image.png](attachment:cf966132-cc4f-406d-b044-bc6c38138b3f.png)

# %%
def solution(money):
    lst = [0, 0]
    lst[0] = (money//5500)
    lst[1] = (money%5500)
    return lst

# %% [markdown]
# ## 옷가게 할인 받기
#
# 머쓱이네 옷가게는 10만 원 이상 사면 5%, 30만 원 이상 사면 10%, 50만 원 이상 사면 20%를 할인해줍니다.
# 구매한 옷의 가격 price가 주어질 때, 지불해야 할 금액을 return 하도록 solution 함수를 완성해보세요.
#
# ![image.png](attachment:307585e6-f087-4f4e-9d32-7246bd598082.png)

# %%
def solution(price):
    if 100000 > price:
        return int(price)
    elif 100000 <= price < 300000:
        return int(price*0.95)
    elif 300000 <= price < 500000:
        return int(price*0.9)
    else:
        return int(price*0.8)
